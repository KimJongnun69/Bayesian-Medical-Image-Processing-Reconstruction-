# %%
import numpy as np
from scipy.special import jv
import matplotlib.pyplot as plt
from scipy.io import loadmat

# %%
# load the images
data = loadmat('assignmentImageDenoising_phantom.mat')
noiseless_image = data['imageNoiseless']
noisy_image = data['imageNoisy']

# Normalize images
max_value = np.max(noisy_image)
noiseless_image = noiseless_image / max_value
noisy_image = noisy_image / max_value

# %%
# Quadratic priors
def prior1(data, row, col, pixel_value, gamma):

    nrows, ncols = data.shape
    total = 0
    for direction in [(1,0), (0,1), (-1,0), (0,-1)]:
        new_row, new_col = (row + direction[0]) % nrows, (col + direction[1]) % ncols
        diff = pixel_value - data[new_row, new_col]
        total += diff
    return total

# Huber prior
def prior2(data, row, col, pixel_value, gamma):
    nrows, ncols = data.shape
    total = 0
    for direction in [(1,0), (0,1), (-1,0), (0,-1)]:
        new_row, new_col = (row + direction[0]) % nrows, (col + direction[1]) % ncols
        diff = pixel_value - data[new_row, new_col]
        if abs(diff) <= gamma:
            total += diff
        else:
            total += gamma * np.sign(diff)
    return total

# Discontinuity-adaptive prior
def prior3(data, row, col, pixel_value, gamma):
    nrows, ncols = data.shape
    total = 0
    for direction in [(1,0), (0,1), (-1,0), (0,-1)]:
        new_row, new_col = (row + direction[0]) % nrows, (col + direction[1]) % ncols
        diff = pixel_value - data[new_row, new_col]
        total += gamma * diff / (gamma + abs(diff))
    return total

# %%
# compute the prior values for all pixels
def compute_prior_matrix(data, prior_func, gamma):
    prior_values = np.zeros(data.shape)
    for row in range(data.shape[0]):
        for col in range(data.shape[1]):
            prior_values[row, col] = prior_func(data, row, col, data[row, col], gamma)
    return prior_values

# %%
# to compute the gradient
def compute_gradient(prior_func, alpha, data_noisy, estimate, gamma):
    return (1 - alpha) * (estimate - data_noisy) + alpha * compute_prior_matrix(estimate, prior_func, gamma)

# %%
# relative root mean squared error
def rrmse(matrix1, matrix2):
    return np.sqrt(np.sum((matrix1 - matrix2)**2)) / np.sqrt(np.sum(matrix1**2))

def posterior(noisy_data, estimate, prior_func, alpha, gamma):

    likelihood_term = -0.5 * np.sum((estimate - noisy_data) ** 2)

    prior_term = -alpha * np.sum(compute_prior_matrix(estimate, prior_func, gamma))

    return likelihood_term + prior_term

# %%
# gradient descent
def gradient_descent(noisy_data, prior_func, alpha, gamma, max_iter=200):
    estimate = noisy_data.copy()
    learning_rate = 0.1
    pos_vals = []

    for iteration in range(max_iter):
        step_size = learning_rate / (1 + iteration/10)

        gradient = compute_gradient(prior_func, alpha, noisy_data, estimate, gamma)
        new_estimate = estimate - step_size * gradient

        new_estimate = np.clip(new_estimate, 0, 1)

        change = np.mean(np.abs(new_estimate - estimate))
        estimate = new_estimate

        log_posterior = posterior(noisy_data, estimate, prior_func, alpha, gamma)
        pos_vals.append(log_posterior)

        if iteration % 5 == 0:
            current_rrmse = rrmse(noiseless_image, estimate)
            print(f"Iteration {iteration}, RRMSE: {current_rrmse:.6f}, Change: {change:.6f}")

        # early termination
        if change < 1e-6:
            print("Converged!")
            break

    return estimate, pos_vals

# %%
# to plot
def plot_results(noiseless, noisy, denoised, alpha, gamma, rrmse_value):
    fig, axes = plt.subplots(2, 2, figsize=(12, 12))

    axes[0, 0].imshow(noiseless, cmap='gray', vmin=0, vmax=1)
    axes[0, 0].set_title('Noiseless Image')

    axes[0, 1].imshow(noisy, cmap='gray', vmin=0, vmax=1)
    axes[0, 1].set_title('Noisy Image')

    axes[1, 0].imshow(denoised, cmap='gray', vmin=0, vmax=1)
    axes[1, 0].set_title(f'Denoised Image (Prior)\nRRMSE: {rrmse_value:.4f}\nα={alpha}, γ={gamma}')

    diff = np.abs(noiseless - denoised)
    axes[1, 1].imshow(diff, cmap='hot', vmin=0, vmax=0.5)
    axes[1, 1].set_title('Difference Map')

    plt.tight_layout()
    plt.show()

# %%
# set up parameters
alpha = 0.18
gamma = 0.25

denoised, _ = gradient_descent(noisy_image, prior3, alpha, gamma)
print(denoised.shape)
final_rrmse = rrmse(noiseless_image, denoised)

print("RRMSE : ", final_rrmse)

# plot_results(noiseless_image, noisy_image, denoised, alpha, gamma, final_rrmse)
# Out:
# Iteration 0, RRMSE: 0.292500, Change: 0.002014
# Iteration 5, RRMSE: 0.277996, Change: 0.000708
# Iteration 10, RRMSE: 0.272772, Change: 0.000344
# Iteration 15, RRMSE: 0.270261, Change: 0.000199
# Iteration 20, RRMSE: 0.268843, Change: 0.000128
# Iteration 25, RRMSE: 0.267957, Change: 0.000088
# Iteration 30, RRMSE: 0.267362, Change: 0.000065
# Iteration 35, RRMSE: 0.266943, Change: 0.000049
# Iteration 40, RRMSE: 0.266634, Change: 0.000038
# Iteration 45, RRMSE: 0.266401, Change: 0.000031
# Iteration 50, RRMSE: 0.266219, Change: 0.000025
# Iteration 55, RRMSE: 0.266075, Change: 0.000021
# Iteration 60, RRMSE: 0.265959, Change: 0.000018
# Iteration 65, RRMSE: 0.265864, Change: 0.000015
# Iteration 70, RRMSE: 0.265785, Change: 0.000013
# Iteration 75, RRMSE: 0.265719, Change: 0.000012
# Iteration 80, RRMSE: 0.265663, Change: 0.000010
# Iteration 85, RRMSE: 0.265615, Change: 0.000009
# Iteration 90, RRMSE: 0.265574, Change: 0.000008
# Iteration 95, RRMSE: 0.265539, Change: 0.000007
# Iteration 100, RRMSE: 0.265508, Change: 0.000007
# Iteration 105, RRMSE: 0.265481, Change: 0.000006
# Iteration 110, RRMSE: 0.265457, Change: 0.000005
# Iteration 115, RRMSE: 0.265436, Change: 0.000005
# Iteration 120, RRMSE: 0.265417, Change: 0.000005
# Iteration 125, RRMSE: 0.265400, Change: 0.000004
# Iteration 130, RRMSE: 0.265385, Change: 0.000004
# Iteration 135, RRMSE: 0.265372, Change: 0.000004
# Iteration 140, RRMSE: 0.265359, Change: 0.000003
# Iteration 145, RRMSE: 0.265348, Change: 0.000003
# Iteration 150, RRMSE: 0.265339, Change: 0.000003
# Iteration 155, RRMSE: 0.265330, Change: 0.000003
# Iteration 160, RRMSE: 0.265321, Change: 0.000003
# Iteration 165, RRMSE: 0.265314, Change: 0.000002
# Iteration 170, RRMSE: 0.265307, Change: 0.000002
# Iteration 175, RRMSE: 0.265301, Change: 0.000002
# Iteration 180, RRMSE: 0.265295, Change: 0.000002
# Iteration 185, RRMSE: 0.265290, Change: 0.000002
# Iteration 190, RRMSE: 0.265285, Change: 0.000002
# Iteration 195, RRMSE: 0.265281, Change: 0.000002
# (256, 256)
# RRMSE :  0.26527757371756183

# %%
def plot_all_results(noiseless, noisy, denoised1, denoised2, denoised3, params):
    fig, axes = plt.subplots(2, 3, figsize=(15, 10))
    plt.subplots_adjust(wspace=0.3, hspace=0.3)

    # global min and max for consistent colormap
    all_images = [noiseless, noisy, denoised1, denoised2, denoised3]
    vmin = min(image.min() for image in all_images)
    vmax = max(image.max() for image in all_images)

    #noiseless image
    im0 = axes[0, 0].imshow(noiseless, cmap='jet', vmin=vmin, vmax=vmax)
    axes[0, 0].set_title('Noiseless Image')
    axes[0, 0].axis('off')

    # noisy image
    axes[0, 1].imshow(noisy, cmap='jet', vmin=vmin, vmax=vmax)
    axes[0, 1].set_title('Noisy Image')
    axes[0, 1].axis('off')

    # denoised image with prior1
    axes[0, 2].imshow(denoised1, cmap='jet', vmin=vmin, vmax=vmax)
    axes[0, 2].set_title(f'Prior 1 (Quadratic)\nRRMSE: {params["rrmse1"]:.4f}\nα={params["alpha1"]:.3f}, γ={params["gamma1"]:.3f}')
    axes[0, 2].axis('off')

    # denoised image with prior2
    axes[1, 0].imshow(denoised2, cmap='jet', vmin=vmin, vmax=vmax)
    axes[1, 0].set_title(f'Prior 2 (Huber)\nRRMSE: {params["rrmse2"]:.4f}\nα={params["alpha2"]:.3f}, γ={params["gamma2"]:.3f}')
    axes[1, 0].axis('off')

    # denoised image with prior3
    axes[1, 1].imshow(denoised3, cmap='jet', vmin=vmin, vmax=vmax)
    axes[1, 1].set_title(f'Prior 3 (Discontinuity-adaptive)\nRRMSE: {params["rrmse3"]:.4f}\nα={params["alpha3"]:.3f}, γ={params["gamma3"]:.3f}')
    axes[1, 1].axis('off')

    # Remove empty subplot
    axes[1, 2].remove()

    # colorbar
    cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])
    fig.colorbar(im0, cax=cbar_ax, label='Pixel Value')

    plt.show()

# %%
# Plot objective functions vs iterations
def plot_posterior(pos_vals1, pos_vals2, pos_vals3):


    # plt.subplot(3,1,1)
    plt.figure(figsize=(10, 7))

    plt.plot(pos_vals1, marker='o', linestyle='-')
    plt.xlabel("Iteration")
    plt.ylabel("-ve Log Posterior Value")
    plt.title("Prior 1")

    # plt.subplot(3,1, 2)

    plt.figure(figsize=(10, 10))
    plt.plot(pos_vals2, marker='o', linestyle='-')

    plt.xlabel("Iteration")
    plt.ylabel("-ve Log Posterior Value")
    plt.title("Prior 2")

    # plt.subplot(3,1,3)
    plt.figure(figsize=(10, 10))
    plt.plot(pos_vals3, marker='o', linestyle='-')

    plt.xlabel("Iteration")
    plt.ylabel("-ve Log Posterior Value")
    plt.title("Prior 3")

    plt.tight_layout()
    # plt.grid()
    plt.show()

# %%
params = {
        'alpha1': 0.11, 'gamma1': 0.01, 'rrmse1': 0.281,  # find optimal
        'alpha2': 0.8, 'gamma2': 0.05, 'rrmse2': 0.250,
        'alpha3': 0.5, 'gamma3': 0.7, 'rrmse3': 0.789 # find optimal
    }

# Get denoised images using optimal parameters
denoised1, pos1 = gradient_descent(noisy_image, prior1, params['alpha1'], params['gamma1'])
denoised2, pos2 = gradient_descent(noisy_image, prior2, params['alpha2'], params['gamma2'])
denoised3, pos3 = gradient_descent(noisy_image, prior3, params['alpha3'], params['gamma3'])

# Create the comparison plot
plot_all_results(noiseless_image, noisy_image, denoised1, denoised2, denoised3, params)
plot_posterior(pos1, pos2, pos3)
# Out:
# Iteration 0, RRMSE: 0.293940, Change: 0.001867
# Iteration 5, RRMSE: 0.284844, Change: 0.000644
# Iteration 10, RRMSE: 0.282526, Change: 0.000311
# Iteration 15, RRMSE: 0.281692, Change: 0.000179
# Iteration 20, RRMSE: 0.281331, Change: 0.000115
# Iteration 25, RRMSE: 0.281157, Change: 0.000079
# Iteration 30, RRMSE: 0.281069, Change: 0.000058
# Iteration 35, RRMSE: 0.281024, Change: 0.000043
# Iteration 40, RRMSE: 0.281001, Change: 0.000034
# Iteration 45, RRMSE: 0.280992, Change: 0.000027
# Iteration 50, RRMSE: 0.280989, Change: 0.000022
# Iteration 55, RRMSE: 0.280991, Change: 0.000018
# Iteration 60, RRMSE: 0.280996, Change: 0.000015
# Iteration 65, RRMSE: 0.281002, Change: 0.000013
# Iteration 70, RRMSE: 0.281008, Change: 0.000011
# Iteration 75, RRMSE: 0.281016, Change: 0.000010
# Iteration 80, RRMSE: 0.281023, Change: 0.000009
# Iteration 85, RRMSE: 0.281030, Change: 0.000008
# Iteration 90, RRMSE: 0.281037, Change: 0.000007
# Iteration 95, RRMSE: 0.281044, Change: 0.000006
# Iteration 100, RRMSE: 0.281051, Change: 0.000005
# Iteration 105, RRMSE: 0.281057, Change: 0.000005
# Iteration 110, RRMSE: 0.281064, Change: 0.000004
# Iteration 115, RRMSE: 0.281069, Change: 0.000004
# Iteration 120, RRMSE: 0.281075, Change: 0.000004
# Iteration 125, RRMSE: 0.281080, Change: 0.000003
# Iteration 130, RRMSE: 0.281086, Change: 0.000003
# Iteration 135, RRMSE: 0.281090, Change: 0.000003
# Iteration 140, RRMSE: 0.281095, Change: 0.000003
# Iteration 145, RRMSE: 0.281100, Change: 0.000003
# Iteration 150, RRMSE: 0.281104, Change: 0.000002
# Iteration 155, RRMSE: 0.281108, Change: 0.000002
# Iteration 160, RRMSE: 0.281112, Change: 0.000002
# Iteration 165, RRMSE: 0.281116, Change: 0.000002
# Iteration 170, RRMSE: 0.281119, Change: 0.000002
# Iteration 175, RRMSE: 0.281123, Change: 0.000002
# Iteration 180, RRMSE: 0.281126, Change: 0.000002
# Iteration 185, RRMSE: 0.281129, Change: 0.000002
# Iteration 190, RRMSE: 0.281132, Change: 0.000001
# Iteration 195, RRMSE: 0.281135, Change: 0.000001
# Iteration 0, RRMSE: 0.277593, Change: 0.007660
# Iteration 5, RRMSE: 0.245665, Change: 0.001518
# Iteration 10, RRMSE: 0.242228, Change: 0.000538
# Iteration 15, RRMSE: 0.242231, Change: 0.000281
# Iteration 20, RRMSE: 0.242859, Change: 0.000180
# Iteration 25, RRMSE: 0.243608, Change: 0.000129
# Iteration 30, RRMSE: 0.244352, Change: 0.000099
# Iteration 35, RRMSE: 0.245058, Change: 0.000079
# Iteration 40, RRMSE: 0.245716, Change: 0.000066
# Iteration 45, RRMSE: 0.246327, Change: 0.000056
# Iteration 50, RRMSE: 0.246894, Change: 0.000048
# Iteration 55, RRMSE: 0.247423, Change: 0.000042
# Iteration 60, RRMSE: 0.247916, Change: 0.000038
# Iteration 65, RRMSE: 0.248377, Change: 0.000034
# Iteration 70, RRMSE: 0.248811, Change: 0.000030
# Iteration 75, RRMSE: 0.249219, Change: 0.000028
# Iteration 80, RRMSE: 0.249604, Change: 0.000025
# Iteration 85, RRMSE: 0.249968, Change: 0.000024
# Iteration 90, RRMSE: 0.250314, Change: 0.000022
# Iteration 95, RRMSE: 0.250642, Change: 0.000020
# Iteration 100, RRMSE: 0.250955, Change: 0.000019
# Iteration 105, RRMSE: 0.251254, Change: 0.000018
# Iteration 110, RRMSE: 0.251540, Change: 0.000017
# Iteration 115, RRMSE: 0.251813, Change: 0.000016
# Iteration 120, RRMSE: 0.252075, Change: 0.000015
# Iteration 125, RRMSE: 0.252327, Change: 0.000014
# Iteration 130, RRMSE: 0.252569, Change: 0.000013
# Iteration 135, RRMSE: 0.252803, Change: 0.000013
# Iteration 140, RRMSE: 0.253028, Change: 0.000012
# Iteration 145, RRMSE: 0.253245, Change: 0.000012
# Iteration 150, RRMSE: 0.253454, Change: 0.000011
# Iteration 155, RRMSE: 0.253657, Change: 0.000011
# Iteration 160, RRMSE: 0.253853, Change: 0.000010
# Iteration 165, RRMSE: 0.254043, Change: 0.000010
# Iteration 170, RRMSE: 0.254228, Change: 0.000009
# Iteration 175, RRMSE: 0.254407, Change: 0.000009
# Iteration 180, RRMSE: 0.254581, Change: 0.000009
# Iteration 185, RRMSE: 0.254750, Change: 0.000008
# Iteration 190, RRMSE: 0.254914, Change: 0.000008
# Iteration 195, RRMSE: 0.255074, Change: 0.000008
# Iteration 0, RRMSE: 0.280883, Change: 0.006899
# Iteration 5, RRMSE: 0.269562, Change: 0.001457
# Iteration 10, RRMSE: 0.276574, Change: 0.000601
# Iteration 15, RRMSE: 0.282768, Change: 0.000330
# Iteration 20, RRMSE: 0.287488, Change: 0.000211
# Iteration 25, RRMSE: 0.291111, Change: 0.000148
# Iteration 30, RRMSE: 0.293959, Change: 0.000110
# Iteration 35, RRMSE: 0.296256, Change: 0.000085
# Iteration 40, RRMSE: 0.298147, Change: 0.000069
# Iteration 45, RRMSE: 0.299734, Change: 0.000056
# Iteration 50, RRMSE: 0.301085, Change: 0.000047
# Iteration 55, RRMSE: 0.302251, Change: 0.000040
# Iteration 60, RRMSE: 0.303269, Change: 0.000035
# Iteration 65, RRMSE: 0.304165, Change: 0.000031
# Iteration 70, RRMSE: 0.304962, Change: 0.000027
# Iteration 75, RRMSE: 0.305676, Change: 0.000024
# Iteration 80, RRMSE: 0.306319, Change: 0.000022
# Iteration 85, RRMSE: 0.306902, Change: 0.000020
# Iteration 90, RRMSE: 0.307433, Change: 0.000018
# Iteration 95, RRMSE: 0.307920, Change: 0.000016
# Iteration 100, RRMSE: 0.308367, Change: 0.000015
# Iteration 105, RRMSE: 0.308780, Change: 0.000014
# Iteration 110, RRMSE: 0.309162, Change: 0.000013
# Iteration 115, RRMSE: 0.309518, Change: 0.000012
# Iteration 120, RRMSE: 0.309849, Change: 0.000011
# Iteration 125, RRMSE: 0.310159, Change: 0.000010
# Iteration 130, RRMSE: 0.310449, Change: 0.000010
# Iteration 135, RRMSE: 0.310722, Change: 0.000009
# Iteration 140, RRMSE: 0.310979, Change: 0.000008
# Iteration 145, RRMSE: 0.311221, Change: 0.000008
# Iteration 150, RRMSE: 0.311450, Change: 0.000008
# Iteration 155, RRMSE: 0.311667, Change: 0.000007
# Iteration 160, RRMSE: 0.311873, Change: 0.000007
# Iteration 165, RRMSE: 0.312068, Change: 0.000006
# Iteration 170, RRMSE: 0.312254, Change: 0.000006
# Iteration 175, RRMSE: 0.312431, Change: 0.000006
# Iteration 180, RRMSE: 0.312600, Change: 0.000006
# Iteration 185, RRMSE: 0.312762, Change: 0.000005
# Iteration 190, RRMSE: 0.312916, Change: 0.000005
# Iteration 195, RRMSE: 0.313064, Change: 0.000005
